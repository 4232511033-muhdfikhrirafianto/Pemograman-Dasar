# %% [markdown]
# <a href="https://colab.research.google.com/github/4232511033-muhdfikhrirafianto/Pemograman-Dasar/blob/main/4232511033_M.Fikhri%20Rafianto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya

NAMA = "Muhammad Fikhri Rafianto"
UMUR = 22
JURUSAN = "RPE"
SEMESTER = 3
MATAKULIAH = 'Pemograman Dasar'
STATUS_LULUS = False

print (NAMA)
print (UMUR)
print (JURUSAN)
print (SEMESTER)
print (MATAKULIAH)
print (STATUS_LULUS)
# Out:
# Muhammad Fikhri Rafianto
# 22
# RPE
# 3
# Pemograman Dasar
# False
